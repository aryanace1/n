# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

df = pd.read_csv('Musical_instruments_reviews.csv')
df['sentiment'] = df['overall'].map({5: 1, 4: -1, 3: 0, 2: -1, 1: -1})

positive_df = df[df['sentiment'] == 1]
neutral_df = df[df['sentiment'] == 0]
negative_df = df[df['sentiment'] == -1]

sample_size = min(len(positive_df), len(neutral_df), len(negative_df))

positive_sample = positive_df.sample(sample_size, random_state=42)
print(positive_sample)
neutral_sample = neutral_df.sample(sample_size, random_state=42)
negative_sample = negative_df.sample(sample_size, random_state=42)
print(negative_sample)

balanced_df = pd.concat([positive_sample, neutral_sample, negative_sample])

train_df, test_df = train_test_split(balanced_df, test_size=0.2, random_state=42)

def calculate_tfidf(corpus):
    tf = {}
    for doc in corpus:
        for word in doc.split():
            tf[word] = tf.get(word, 0) + 1

    idf = {}
    for doc in corpus:
        for word in set(doc.split()):
            idf[word] = idf.get(word, 0) + 1

    tfidf = {}
    for word, tf_value in tf.items():
        idf_value = np.log(len(corpus) / (idf[word] + 1))
        tfidf[word] = tf_value * idf_value
    return tfidf

tfidf_dict = calculate_tfidf(train_df['summary'])
train_tfidf = train_df['summary'].apply(lambda x: sum(tfidf_dict.get(word, 0) for word in x.split()))

X_train = np.array(train_tfidf.tolist()).reshape(-1, 1)
y_train = train_df['sentiment'].values

model = LogisticRegression(random_state=42)
model.fit(X_train, y_train)

def predict_sentiment(review, threshold=0.32):
    review_tfidf = sum(tfidf_dict.get(word, 0) for word in review.split())
    X_new = np.array([review_tfidf]).reshape(-1, 1)

    probability_positive = model.predict_proba(X_new)[0, 1]
    #print(probability_positive)
    
    if probability_positive > threshold:
        return 'Positive'
    elif probability_positive < threshold-0.007:
        return 'Neutral'
    else:
        return 'Negative'

new_review = "Useless product"
predicted_sentiment = predict_sentiment(new_review)
print(f"Predicted Sentiment: {predicted_sentiment}")
# Out:
#           reviewerID        asin          reviewerName helpful  \
# 3272  A2KXINV90T91L8  B0002M6CVC              David T.  [0, 0]
# 7843  A1JCRZEQACX4V4  B003BFYDBS        Colin Hendrick  [0, 0]
# 4047  A2D0F87RY5YMHN  B0009G1KEU         Levis Ouellet  [0, 0]
# 3871  A1RGF9CS1V8O14  B000960KNW             Josiah H.  [0, 0]
# 9410  A1DVUFG2QSJ6IK  B005T800V2       grandpa "Randy"  [0, 0]
# ...              ...         ...                   ...     ...
# 8867  A109ME7C09HM2M  B004XNK7AI    Douglas W. Fielder  [1, 1]
# 5770  A35XRT4BW4I6UD  B000VJJQUU     Richard R. Casper  [1, 1]
# 7052  A3N93PUHEMQU34  B002024UDE  L. Su "Flying train"  [1, 2]
# 2273   A1JNNQAUI5FZV  B0002GLCRC                 Cliff  [0, 0]
# 1953   ADH0O8UVJOT10  B0002F4VBM              StormJH1  [1, 1]
#
#                                              reviewText  overall  \
# 3272  This are some great strings. I have bought the...      5.0
# 7843  Never used this seller or site for this purpos...      5.0
# 4047  I love my Levy's Jacquard Straps.  They are co...      5.0
# 3871  I've only had these strap locks for a couple w...      5.0
# 9410  Good deal on this package of patch cords. They...      5.0
# ...                                                 ...      ...
# 8867  This little Snark is easy to carry around and ...      5.0
# 5770  I don't use it for any heavy use.  I use it fo...      5.0
# 7052  It's a working violin. My daughter likes it. H...      5.0
# 2273  I like to display my guitars while also keepin...      5.0
# 1953  If you listen or read what many pro guitarists...      5.0
#
#                                     summary  unixReviewTime   reviewTime  \
# 3272                          Great Strings      1388793600   01 4, 2014
# 7843              These are really the best      1352246400   11 7, 2012
# 4047            Awwesome Guitar Straps.....      1384905600  11 20, 2013
# 3871          Schaller Security Strap Locks      1377820800  08 30, 2013
# 9410                            Patch cords      1373932800  07 16, 2013
# ...                                     ...             ...          ...
# 8867                  Great Little Tuner...      1389484800  01 12, 2014
# 5770                          Works for me.      1339372800  06 11, 2012
# 7052                             Good stuff      1328313600   02 4, 2012
# 2273                        Child-resistant      1360108800   02 6, 2013
# 1953  Outstanding value for versatile tone!      1347494400  09 13, 2012
#
#       sentiment
# 3272          1
# 7843          1
# 4047          1
# 3871          1
# 9410          1
# ...         ...
# 8867          1
# 5770          1
# 7052          1
# 2273          1
# 1953          1
#
# [772 rows x 10 columns]
#           reviewerID        asin                reviewerName  helpful  \
# 200   A34IJACMU8C3IM  B0000AQRST          Rob W. "Sounddude"  [9, 10]
# 682   A2T372SGRFAWYP  B0002D01K4           MK Hill "MK Hill"   [0, 0]
# 9016  A3QNHDUBMA6WQM  B0055V7UR0                     John G.   [1, 1]
# 879   A3MPMALWL0ERCA  B0002D0CIK  Walter S. Early "earlyfam"   [0, 0]
# 7682  A34O0KQV4QXWNQ  B0037ME50Y                 Dako "Dako"   [0, 0]
# ...              ...         ...                         ...      ...
# 5685  A18ZKZXXA3WHSJ  B000ULAP4U                      Edward   [0, 3]
# 4805  A1LS2UXHG1BYRG  B000J5XS3C    Carlos De Cunha "Carlos"   [0, 0]
# 1183  A1OV2BH2S11KBA  B0002DV7U2                    jsnchmpn   [1, 2]
# 1124  A1A9DIM802STMK  B0002D0Q2W              Daniel Freeman   [1, 2]
# 2883  A2PFX6WO88KTYB  B0002H0A3S                         miT   [0, 0]
#
#                                              reviewText  overall  \
# 200   Considering that the SM57 was introduced to th...      4.0
# 682   I do some guitar repair work and one of my cus...      4.0
# 9016  Not cheap as far as pics are concerned, but it...      4.0
# 879   I've been trying to find a pick which combines...      4.0
# 7682  I ended up ordering this cable to connect my b...      4.0
# ...                                                 ...      ...
# 5685  I was expecting to be taken to heaven with the...      4.0
# 4805  Great little mixing console for home use and p...      4.0
# 1183  ...for something, but not a guitar.  Wasn't su...      1.0
# 1124  This is a basic EQ pedal, that is a bit noisy ...      2.0
# 2883  I bought these primarily because they are so c...      4.0
#
#                                                 summary  unixReviewTime  \
# 200        One Half Of Shure's Long Lasting Dynamic Duo      1229126400
# 682                                       Epiphone case      1398211200
# 9016  Good variety of pics to figure out just what y...      1393891200
# 879                                        Worth a try.      1375315200
# 7682  Perfect For Connecting A Segment Of Pedals On ...      1389571200
# ...                                                 ...             ...
# 5685                      Overrated Trust me (Ath-M50s)      1402617600
# 4805                                        Great Mixer      1312243200
# 1183                                       Great Mount!      1389225600
# 1124                                     Buzzy buz buzz      1360972800
# 2883           Good strings, nothing more, nothing less      1318896000
#
#        reviewTime  sentiment
# 200   12 13, 2008         -1
# 682   04 23, 2014         -1
# 9016   03 4, 2014         -1
# 879    08 1, 2013         -1
# 7682  01 13, 2014         -1
# ...           ...        ...
# 5685  06 13, 2014         -1
# 4805   08 2, 2011         -1
# 1183   01 9, 2014         -1
# 1124  02 16, 2013         -1
# 2883  10 18, 2011         -1
#
# [772 rows x 10 columns]
# Predicted Sentiment: Neutral
